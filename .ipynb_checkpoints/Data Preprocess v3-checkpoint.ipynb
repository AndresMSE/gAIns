# %%
import pandas as pd
import time
import datetime
import numpy as np
import matplotlib.pyplot as plt
import SSA as ss
from datetime import datetime
import re

# %% [markdown]
# # Deploying API

# %%
pd.set_option('display.notebook_repr_html', True)
ticker = 'AAPL'
period1 = int(time.mktime(datetime(2015,10,28,20,1).timetuple()))
period2 = int(time.mktime(datetime(2021,11,28,20,1).timetuple()))
interval = '1d' #1w 1m 1y
url_string = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'

print(url_string)
data = pd.read_csv(url_string,sep=r',')
data
# Out:
# https://query1.finance.yahoo.com/v7/finance/download/AAPL?period1=1446084060&period2=1638151260&interval=1d&events=history&includeAdjustedClose=true
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-10-29   29.674999   30.172501   29.567499   30.132500   27.627590
# 1     2015-10-30   30.247499   30.305000   29.862499   29.875000   27.391500
# 2     2015-11-02   30.200001   30.340000   29.902500   30.295000   27.776583
# 3     2015-11-03   30.197500   30.872499   30.174999   30.642500   28.095196
# 4     2015-11-04   30.782499   30.955000   30.405001   30.500000   27.964542
# ...          ...         ...         ...         ...         ...         ...
# 1526  2021-11-19  157.649994  161.020004  156.529999  160.550003  160.550003
# 1527  2021-11-22  161.679993  165.699997  161.000000  161.020004  161.020004
# 1528  2021-11-23  161.119995  161.800003  159.059998  161.410004  161.410004
# 1529  2021-11-24  160.750000  162.139999  159.639999  161.940002  161.940002
# 1530  2021-11-26  159.570007  160.449997  156.360001  156.809998  156.809998
#
#          Volume
# 0     204909200
# 1     197461200
# 2     128813200
# 3     182076000
# 4     179544400
# ...         ...
# 1526  117305600
# 1527  117467900
# 1528   96041900
# 1529   69463600
# 1530   76959800
#
# [1531 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1531 entries, 0 to 1530
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1531 non-null   object
#  1   Open       1531 non-null   float64
#  2   High       1531 non-null   float64
#  3   Low        1531 non-null   float64
#  4   Close      1531 non-null   float64
#  5   Adj Close  1531 non-null   float64
#  6   Volume     1531 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 83.9+ KB

# %% [markdown]
# # Index Selection
#
# ![table1](index.png)

# %%
x1 = data['Close'].to_numpy()
x2 = data['Open'].to_numpy()
x3 = data['High'].to_numpy()
x4 = data['Low'].to_numpy()
x5 = data['Volume'].to_numpy()

# %%
#Data normalization
for i in range(5):
    name = f'x{i+1}'
    var = globals()[name]
    globals()[name] = (var-var.mean())/var.std()

# %%
x1
# Out:
# array([-0.85984414, -0.8664057 , -0.85570335, ...,  2.48534229,
#         2.4988476 ,  2.36812589])

# %%
globals()['x1']
# Out:
# array([-0.85984414, -0.8664057 , -0.85570335, ...,  2.48534229,
#         2.4988476 ,  2.36812589])

# %%
(data['Close'].to_numpy() - data['Close'].to_numpy().mean())/data['Close'].to_numpy().std()
# Out:
# array([-0.85984414, -0.8664057 , -0.85570335, ...,  2.48534229,
#         2.4988476 ,  2.36812589])

# %% [markdown]
# # Dataset filtering
#
# Let's look up for the scree diagram of the Yahoo finance dataset

# %%
L = int(len(x1)/2)

# %%
print('Tiempo =',str(datetime.now()))
l=ss.ScreeD(x1,L)
print('Tiempo=',str(datetime.now()))
k=np.arange(len(l))
k=k+1
fig,axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(k,l,'-x',color='blue')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Número de órden k')
axs[0].set_ylabel(r'Varianza parcial $\lambda_k$')
axs[0].grid()

axs[1].plot(k,l/sum(l),'-x',color='blue')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_xlabel('Número de órden k')
axs[1].set_ylabel(r'Varianza parcial fraccional $\lambda_k/\lambda_{tot}$')
axs[1].grid()
plt.title('Scree diagram x1')
plt.show()
# Out:
# Tiempo = 2022-01-06 17:56:59.017290
# Tiempo= 2022-01-06 17:56:59.423378

# %%
print('Tiempo =',str(datetime.now()))
l=ss.ScreeD(x2,L)
print('Tiempo=',str(datetime.now()))
k=np.arange(len(l))
k=k+1
fig,axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(k,l,'-x',color='blue')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Número de órden k')
axs[0].set_ylabel(r'Varianza parcial $\lambda_k$')
axs[0].grid()

axs[1].plot(k,l/sum(l),'-x',color='blue')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_xlabel('Número de órden k')
axs[1].set_ylabel(r'Varianza parcial fraccional $\lambda_k/\lambda_{tot}$')
axs[1].grid()
plt.title('Scree diagram x2')
plt.show()
# Out:
# Tiempo = 2022-01-06 17:57:01.517549
# Tiempo= 2022-01-06 17:57:02.009269

# %%
print('Tiempo =',str(datetime.now()))
l=ss.ScreeD(x3,L)
print('Tiempo=',str(datetime.now()))
k=np.arange(len(l))
k=k+1
fig,axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(k,l,'-x',color='blue')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Número de órden k')
axs[0].set_ylabel(r'Varianza parcial $\lambda_k$')
axs[0].grid()

axs[1].plot(k,l/sum(l),'-x',color='blue')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_xlabel('Número de órden k')
axs[1].set_ylabel(r'Varianza parcial fraccional $\lambda_k/\lambda_{tot}$')
axs[1].grid()
plt.title('Scree diagram x3')
plt.show()
# Out:
# Tiempo = 2022-01-06 17:57:03.512830
# Tiempo= 2022-01-06 17:57:04.009545

# %%
print('Tiempo =',str(datetime.now()))
l=ss.ScreeD(x4,L)
print('Tiempo=',str(datetime.now()))
k=np.arange(len(l))
k=k+1
fig,axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(k,l,'-x',color='blue')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Número de órden k')
axs[0].set_ylabel(r'Varianza parcial $\lambda_k$')
axs[0].grid()

axs[1].plot(k,l/sum(l),'-x',color='blue')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_xlabel('Número de órden k')
axs[1].set_ylabel(r'Varianza parcial fraccional $\lambda_k/\lambda_{tot}$')
axs[1].grid()
plt.title('Scree diagram x4')
plt.show()
# Out:
# Tiempo = 2022-01-06 17:57:05.640432
# Tiempo= 2022-01-06 17:57:06.090174

# %%
print('Tiempo =',str(datetime.now()))
l=ss.ScreeD(x5,L)
print('Tiempo=',str(datetime.now()))
k=np.arange(len(l))
k=k+1
fig,axs = plt.subplots(1,2,figsize=(15,5))
axs[0].plot(k,l,'-x',color='blue')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Número de órden k')
axs[0].set_ylabel(r'Varianza parcial $\lambda_k$')
axs[0].grid()

axs[1].plot(k,l/sum(l),'-x',color='blue')
axs[1].set_xscale('log')
axs[1].set_yscale('log')
axs[1].set_xlabel('Número de órden k')
axs[1].set_ylabel(r'Varianza parcial fraccional $\lambda_k/\lambda_{tot}$')
axs[1].grid()
plt.title('Scree diagram x5')
plt.show()
# Out:
# Tiempo = 2022-01-06 17:57:07.635890
# Tiempo= 2022-01-06 17:57:08.086632

# %% [markdown]
# Now let's check the correlation matrix of these same index

# %% [markdown]
# # Get the SSA results from the base

# %%
def indexSSA(series,L,name):
    tin=datetime.now()
    print('Tiempo @ inicio =',str(datetime.now()))
    l,gklist,wMatrix = ss.SSA(series,L)
    tfin = datetime.now()
    print('Tiempo @ final =',str(datetime.now()))
    delta = tfin-tin
    sec,milisec = re.findall('\d+',str(delta))[2],re.findall('\d+',str(delta))[3]
    print(f'SSA de la serie {name} completado! Tomó {sec} sec con {milisec} milisec!')
    return l,gklist,wMatrix

# %%
for i in range(5):
    name = f'x{i+1}'
    lname,gkname,wMatname  = name + '_l',name+'_gklist',name+'_wMatrix'
    t1,t2,t3 = indexSSA(globals()[name],L,name)
    locals()[lname] =t1
    locals()[gkname] = t2
    locals()[wMatname] = t3
# Out:
# Tiempo @ inicio = 2022-01-06 17:57:10.447799
# Tiempo @ final = 2022-01-06 17:57:38.829651
# SSA de la serie x1 completado! Tomó 28 sec con 381852 milisec!
# Tiempo @ inicio = 2022-01-06 17:57:38.830651
# Tiempo @ final = 2022-01-06 17:58:04.215028
# SSA de la serie x2 completado! Tomó 25 sec con 384377 milisec!
# Tiempo @ inicio = 2022-01-06 17:58:04.215028
# Tiempo @ final = 2022-01-06 17:58:29.997444
# SSA de la serie x3 completado! Tomó 25 sec con 782416 milisec!
# Tiempo @ inicio = 2022-01-06 17:58:29.997444
# Tiempo @ final = 2022-01-06 17:58:56.857434
# SSA de la serie x4 completado! Tomó 26 sec con 859990 milisec!
# Tiempo @ inicio = 2022-01-06 17:58:56.858977
# Tiempo @ final = 2022-01-06 17:59:21.184873
# SSA de la serie x5 completado! Tomó 24 sec con 325896 milisec!

# %%
x1_gklist.shape
# Out:
# (765, 1531)

# %% [markdown]
# # Correlation matrix
#
# ## x1 closing

# %%
x=np.arange(1, 20, 2)
y=x+1
plt.figure(figsize=(15,7)) #Declaramos el espacio de figura para graficar
plt.imshow(x1_wMatrix,cmap=plt.cm.binary);
plt.colorbar()
plt.xticks(x,y)
plt.yticks(x,y)
plt.show()

# %% [markdown]
# ## x2 opening

# %%
x=np.arange(1, 20, 2)
y=x+1
plt.figure(figsize=(15,7)) #Declaramos el espacio de figura para graficar
plt.imshow(x2_wMatrix,cmap=plt.cm.binary);
plt.colorbar()
plt.xticks(x,y)
plt.yticks(x,y)
plt.show()

# %% [markdown]
# ## x3 Highest

# %%
x=np.arange(1, 20, 2)
y=x+1
plt.figure(figsize=(15,7)) #Declaramos el espacio de figura para graficar
plt.imshow(x3_wMatrix,cmap=plt.cm.binary);
plt.colorbar()
plt.xticks(x,y)
plt.yticks(x,y)
plt.show()

# %% [markdown]
# ## x4 Lowest

# %%
x=np.arange(1, 20, 2)
y=x+1
plt.figure(figsize=(15,7)) #Declaramos el espacio de figura para graficar
plt.imshow(x4_wMatrix,cmap=plt.cm.binary);
plt.colorbar()
plt.xticks(x,y)
plt.yticks(x,y)
plt.show()

# %% [markdown]
# ## x5 Volume

# %%
x=np.arange(1, 20, 2)
y=x+1
plt.figure(figsize=(15,7)) #Declaramos el espacio de figura para graficar
plt.imshow(x5_wMatrix,cmap=plt.cm.binary);
plt.colorbar()
plt.xticks(x,y)
plt.yticks(x,y)
plt.show()

# %% [markdown]
# # gk[0] (trend) vs series

# %%
fig, ax = plt.subplots(5,1,figsize=(15,20))
max_comp = 30
for i in range(5):
    name = f"x{i+1}"
    name_ssa = name + "_gklist"
    ax[i].plot(globals()[name],label='Series')
    ax[i].plot(globals()[name_ssa][0],label='Trend')
    ax[i].plot(globals()[name_ssa][0] + globals()[name_ssa][1] + globals()[name_ssa][2] ,label='Trend + C1')
    #Find optimal elements
    
    Filtered = [element for element in globals()[name_ssa][0:max_comp] ]
    ax[i].plot(sum(Filtered),label='Sum')
    ax[i].set_title(f'{name}')
    ax[i].grid()
    ax[i].legend()

# %% [markdown]
# # The "optimal" filtered series given the first elements of the decomposition of SSA will be the new index used to calculate the next complex index

# %%
for i in range(5):
    name = f'x{i+1}'
    name_ssa = name + "_gklist"
    Filtered = [element for element in globals()[name_ssa][0:max_comp] ]
    locals()[name] = sum(Filtered)

# %%
# 5-day average trading volume ATV(5)
x6 = np.zeros(len(x5)-4)
for i in range(len(x5)-4):
    prom = sum(x5[i:i+5])/5
    x6[i] = prom

# %%
plt.plot(x6)
plt.title('ATV(5)')
plt.xlabel('5-day element')
plt.ylabel('Volumen average')
plt.show()

# %%
#20-day average trading volume ATV(20)
x7 = np.zeros(len(x5)-19)
for i in range(len(x5)-19):
    prom = sum(x5[i:i+20])/20
    x7[i] = prom

# %%
plt.plot(x7)
# plt.plot(x5)
plt.title('ATV(20)')
plt.xlabel('20-day element')
plt.ylabel('Volumen average')
plt.show()

# %%
#5-day moving average MA(5)
x8 = np.zeros(len(x2)-4)
for i in range(len(x2)-4):
    prom = sum(x2[i:i+5])/5
    x8[i] = prom

# %%
plt.plot(x8)
# plt.plot(x1)
plt.title('Opening MA(5)')
plt.xlabel('5-day element')
plt.ylabel('Opening average')
plt.show()

# %%
#20-day moving average MA(20)
x9 = np.zeros(len(x2)-19)
for i in range(len(x2)-19):
    prom = sum(x2[i:i+20])/20
    x9[i] = prom

# %%
plt.plot(x9)
# plt.plot(x1)
plt.title('Opening MA(20)')
plt.xlabel('20-day element')
plt.ylabel('Opening average')
plt.show()

# %%
#12-day exponential moving average EXMA(12)
x10 = np.zeros(len(x2))
s = 2/(12+1)
x10[0] = sum(x1[:12])/12
for i in range(len(x2)-1):
    EMAi = x1[i+1]*s + x10[i]*(1-s)  
    x10[i+1] = EMAi

# %%
plt.plot(x10)
plt.title('Closing EMA(12)')
plt.xlabel('12-day element')
plt.ylabel('Closing exp average')
plt.show()

# %% [markdown]
# $$EMA_t = [V_t (\frac{s}{1+d})]+EMA_y[1-(\frac{s}{1+d})]$$
#
# $s:=$ 2/selected time period+1
#
# $V_t:=$ value today
#
# $d:=$ number of days
#
# $EMA_y:=$ EMA yesterday

# %%
#26-day exponential moving average EXMA(26)
x11aux = np.zeros(len(x1))
s = 2/(26+1)
x11aux[0] = sum(x1[0:26])/26
for i in range(len(x2)-1):
    EMAi = x1[i+1]*s + x11aux[i]*(1-s)  
    x11aux[i+1] = EMAi
#MACD
x11= x10-x11aux

# %%
plt.plot(x11)
plt.title('Closing MACD')
plt.xlabel('day')
plt.show()

# %% [markdown]
# ### MACD = 12-Period EMA - 26-Period EMA

# %%
gain = -data['Open']+data['Close']

# %%
gain.to_numpy()
# Out:
# array([ 0.457501, -0.372499,  0.094999, ...,  0.290009,  1.190002,
#        -2.760009])

# %%
tgain = np.zeros(len(gain))
tloss = np.zeros(len(gain))
for i in range(len(gain)):
    if gain[i] >=0:
        tgain[i] = gain[i]
    else:
        tloss[i] = abs(gain[i])

# %%
tgain
# Out:
# array([0.457501, 0.      , 0.094999, ..., 0.290009, 1.190002, 0.      ])

# %%
tloss
# Out:
# array([0.      , 0.372499, 0.      , ..., 0.      , 0.      , 2.760009])

# %%
plt.plot(tgain[:10],label='tgain')
plt.plot(tloss[:10],label='tloss')
plt.legend()
plt.show()

# %%
favg_gain = np.zeros(len(tgain)-8)
for i in range(len(tgain)-8):
    prom = sum(tgain[i:i+9])/9
    favg_gain[i] = prom
favg_loss = np.zeros(len(tloss)-8)
for i in range(len(tloss)-8):
    prom = sum(tloss[i:i+9])/9
    favg_loss[i] = prom

avg_gain = np.zeros(len(tgain))
avg_loss = np.zeros(len(tgain))
avg_gain[0] = favg_gain[0]
avg_loss[0] = favg_loss[0]
x12 = np.zeros(len(tgain))
for i in range(len(tgain)-1):
    avgai = ( tgain[i+1] + avg_gain[i]*(8)  )/9
    avloss = ( tloss[i+1] + avg_loss[i]*(8)  )/9
    avg_gain[i+1] = avgai
    avg_loss[i+1] = avloss
    RS = avgai/avloss
    RSIi = 100-100/(1+RS)
    x12[i+1] = RSIi

# %%
plt.plot(x12)
plt.title('Relative Strength index RSI(9)')
plt.xlabel('day')
plt.show()

# %%
def ADX(data, period):
    """
    Computes the ADX indicator.
    """
    
    df = data.copy()
    alpha = 1/period

    # TR
    df['H-L'] = df['High'] - df['Low']
    df['H-C'] = np.abs(df['High'] - df['Close'].shift(1))
    df['L-C'] = np.abs(df['Low'] - df['Close'].shift(1))
    df['TR'] = df[['H-L', 'H-C', 'L-C']].max(axis=1)
    del df['H-L'], df['H-C'], df['L-C']

    # ATR
    df['ATR'] = df['TR'].ewm(alpha=alpha, adjust=False).mean()

    # +-DX
    df['H-pH'] = df['High'] - df['High'].shift(1)
    df['pL-L'] = df['Low'].shift(1) - df['Low']
    df['+DX'] = np.where(
        (df['H-pH'] > df['pL-L']) & (df['H-pH']>0),
        df['H-pH'],
        0.0
    )
    df['-DX'] = np.where(
        (df['H-pH'] < df['pL-L']) & (df['pL-L']>0),
        df['pL-L'],
        0.0
    )
    del df['H-pH'], df['pL-L']

    # +- DMI
    df['S+DM'] = df['+DX'].ewm(alpha=alpha, adjust=False).mean()
    df['S-DM'] = df['-DX'].ewm(alpha=alpha, adjust=False).mean()
    df['+DMI'] = (df['S+DM']/df['ATR'])*100
    df['-DMI'] = (df['S-DM']/df['ATR'])*100
    del df['S+DM'], df['S-DM']

    # ADX
    df['DX'] = (np.abs(df['+DMI'] - df['-DMI'])/(df['+DMI'] + df['-DMI']))*100
    df['ADX'] = df['DX'].ewm(alpha=alpha, adjust=False).mean()
    del df['DX'], df['ATR'], df['TR'], df['-DX'], df['+DX'], df['+DMI'], df['-DMI']

    return df

# %%
Adx = ADX(data,14)
x13 = Adx['ADX'].to_numpy()

# %%
plt.plot(x13)

# %% [markdown]
# # DataBase

# %%
Base1 = pd.DataFrame()

# %%
Base1['Date'] = data['Date'][19:len(x1)]
for i in range(13):
    name = 'x'+f'{i+1}'
    index = globals()[name] 
    if  0<i<5:
        Base1[name] = index[19:len(x1)]
    elif i == 5 or i == 7 :
        Base1[name] = index[15:len(x1)]
    elif i == 6 or i ==8:
        Base1[name] = index
    else:
        Base1[name] = index[19:len(x1)]

# %%
Base1
# Out:
#             Date        x1        x2        x3        x4        x5        x6  \
# 19    2015-11-25 -0.921688 -0.920092 -0.919768 -0.922138  0.134749  0.281809
# 20    2015-11-27 -0.921368 -0.919441 -0.919273 -0.921406 -0.025291  0.227779
# 21    2015-11-30 -0.921172 -0.918960 -0.918907 -0.920929 -0.121850  0.131590
# 22    2015-12-01 -0.921093 -0.918637 -0.918679 -0.920702 -0.120239  0.031942
# 23    2015-12-02 -0.921095 -0.918491 -0.918554 -0.920702 -0.010914 -0.028709
# ...          ...       ...       ...       ...       ...       ...       ...
# 1526  2021-11-19  2.404361  2.384329  2.392809  2.401664 -0.387734 -0.705945
# 1527  2021-11-22  2.445565  2.437101  2.433961  2.454403 -0.414325 -0.568126
# 1528  2021-11-23  2.484601  2.485706  2.467153  2.501690 -0.521204 -0.492339
# 1529  2021-11-24  2.519519  2.528601  2.496901  2.543852 -0.642846 -0.487974
# 1530  2021-11-26  2.540844  2.563174  2.520189  2.573452 -0.706435 -0.534509
#
#             x7        x8        x9       x10       x11        x12        x13
# 19    0.712854 -0.922043 -0.932628 -0.928274  0.003094  47.533255  53.629003
# 20    0.630299 -0.921075 -0.931407 -0.927212  0.003416  45.205053  51.204899
# 21    0.552546 -0.920263 -0.930197 -0.926283  0.003645  47.088083  48.219972
# 22    0.482689 -0.919613 -0.929015 -0.925484  0.003789  40.046351  45.940183
# 23    0.420685 -0.919124 -0.927867 -0.924809  0.003858  35.550144  44.223505
# ...        ...       ...       ...       ...       ...        ...        ...
# 1526 -0.915521  2.295326  2.213718  2.270148  0.058628  81.604508  20.410311
# 1527 -0.879821  2.338857  2.225595  2.297135  0.068278  77.842768  23.283500
# 1528 -0.856668  2.385891  2.239447  2.325976  0.078175  78.336433  25.009375
# 1529 -0.842822  2.433887  2.255260  2.355752  0.087824  80.356745  26.669258
# 1530 -0.831956  2.479782  2.272869  2.384228  0.096084  64.630022  26.761506
#
# [1512 rows x 14 columns]

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-10-29   29.674999   30.172501   29.567499   30.132500   27.627590
# 1     2015-10-30   30.247499   30.305000   29.862499   29.875000   27.391500
# 2     2015-11-02   30.200001   30.340000   29.902500   30.295000   27.776583
# 3     2015-11-03   30.197500   30.872499   30.174999   30.642500   28.095196
# 4     2015-11-04   30.782499   30.955000   30.405001   30.500000   27.964542
# ...          ...         ...         ...         ...         ...         ...
# 1526  2021-11-19  157.649994  161.020004  156.529999  160.550003  160.550003
# 1527  2021-11-22  161.679993  165.699997  161.000000  161.020004  161.020004
# 1528  2021-11-23  161.119995  161.800003  159.059998  161.410004  161.410004
# 1529  2021-11-24  160.750000  162.139999  159.639999  161.940002  161.940002
# 1530  2021-11-26  159.570007  160.449997  156.360001  156.809998  156.809998
#
#          Volume
# 0     204909200
# 1     197461200
# 2     128813200
# 3     182076000
# 4     179544400
# ...         ...
# 1526  117305600
# 1527  117467900
# 1528   96041900
# 1529   69463600
# 1530   76959800
#
# [1531 rows x 7 columns]

# %%
for i in range(13):
    name = 'x'+f'{i+1}'
    index = globals()[name]
    print(index.shape)
# Out:
# (1531,)
# (1531,)
# (1531,)
# (1531,)
# (1531,)
# (1527,)
# (1512,)
# (1527,)
# (1512,)
# (1531,)
# (1531,)
# (1531,)
# (1531,)

# %% [markdown]
# # Error between filtered and og series

# %%
fig, ax = plt.subplots(5,1,figsize=(15,20))
max_comp = 30
for i in range(5):
    name = f"x{i+1}"
    col = data.columns
    name_ssa = name + "_gklist"
    Filtered = [element for element in globals()[name_ssa][0:max_comp] ]
    og = (data[col[i+1]].to_numpy() - data[col[i+1]].to_numpy().mean())/data[col[i+1]].to_numpy().std()
    ax[i].plot(abs(og-sum(Filtered))/og.max(),label='Error',c='black')
    ax[i].set_title(f'{name}')
    ax[i].grid()
    ax[i].legend()
